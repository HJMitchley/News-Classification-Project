# %% [markdown]
# Classification of news articles:
#
# https://www.kaggle.com/datasets/rmisra/news-category-dataset
#
#
# > Can you categorize news articles based on their headlines and short descriptions?

# %%
import pandas as pd

# %%
data_df = pd.read_json('News_Category_Dataset_v3.json',  lines=True)

# %%
data_df.head(5)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
data_df.category.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         U.S. NEWS
# 1         U.S. NEWS
# 2            COMEDY
# 3         PARENTING
# 4         U.S. NEWS
#             ...
# 209522         TECH
# 209523       SPORTS
# 209524       SPORTS
# 209525       SPORTS
# 209526       SPORTS
# Name: category, Length: 209527, dtype: object>

# %%
data_df.groupby("category").count().sort_values(by=["link"])
# Out:
#                  link  headline  short_description  authors   date
# category
# EDUCATION        1014      1014               1014     1014   1014
# CULTURE & ARTS   1074      1074               1074     1074   1074
# LATINO VOICES    1130      1130               1130     1130   1130
# COLLEGE          1144      1144               1144     1144   1144
# ARTS & CULTURE   1339      1339               1339     1339   1339
# U.S. NEWS        1377      1377               1377     1377   1377
# GOOD NEWS        1398      1398               1398     1398   1398
# FIFTY            1401      1401               1401     1401   1401
# ENVIRONMENT      1444      1444               1444     1444   1444
# ARTS             1509      1509               1509     1509   1509
# MONEY            1756      1756               1756     1756   1756
# TASTE            2096      2096               2096     2096   2096
# TECH             2104      2104               2104     2104   2104
# ...

# %% [markdown]
# Potential categories:
#
#      Politics
#      world news
#      Us news
#      Sports
#      Wellness + Healthy Living
#      Travel
#      Entertainment
#      Queer Voices
#      Black Voices
#      Style & Beauty
#      Parenting (+Parents)
#      Food & Drink
#
# One approach we should do: catagoirizing using TF-IDF (see explanation of TF-IDF here https://monkeylearn.com/blog/what-is-tf-idf/)

# %% [markdown]
# Next steps:
#
#     1. Save data as a dataframe (rather than JSON)
#     2. Cleaning - save copy with only the relevant catgories and columns, removing rows with missing info?
#     3. Cleaning - preprocessing the data (lowercase, remove stop words, remove punctuation, stemming, lemmatization, convert numbers to words)
#     4. Train-test-split, KFold, etc
#     5. Calculate TD-IDF
#        here is an explanation of how to do TF-IDF:
#        https://towardsdatascience.com/tf-idf-for-document-ranking-from-scratch-in-python-on-real-world-dataset-796d339a4089
#     6. Ranking using one/more of the methods mention in the above link

# %% [markdown]
# Other things we could do? (Josh has some interesting ideas - please make notes here)

# %% [markdown]
# ### thoughts about how to progress
#
#     -  we're adding columns of cleaned up sentences for the headlines and short descriptions
#     - we'll have a single for-loop to do all the cleaning, and only after all the cleaning is done for a given entry will we add the cleaned up data to the df (rather than
#     -  when the time comes to run calculate the td-idf, we'll have to retrieve those cleaned up sentences,
#         add them to a list of other cleaned up sentences for that new category, then tokenize that list
#     - then we get the tf-idf for each list (for each category)
