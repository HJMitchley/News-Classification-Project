# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from num2words import num2words # needed to install num2words first
import string

# %%
## Only need to do this once

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords') ## Others might need to dl this still
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ayanm\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ayanm\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ayanm\AppData\Roaming\nltk_data...
# True

# %%
df=pd.read_json('./News_Category_Dataset_v3.json', lines=True)

# %%
## making columns
df['headline_cleaned']=df['headline']
df['short_description_cleaned']=df['short_description']
df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2       23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3       The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
# ...                                                   ...        ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...       TECH
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...     SPORTS
# 209524  Giants Over Patriots, Jets Over Colts Among  M...     SPORTS
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...     SPORTS
# 209526  Dwight Howard Rips Teammates After Magic Loss ...     SPORTS
#
#                                         short_description  \
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
#                      authors       date  \
# 0       Carla K. Johnson, AP 2022-09-23
# 1             Mary Papenfuss 2022-09-23
# 2              Elyse Wanshel 2022-09-23
# 3           Caroline Bologna 2022-09-23
# 4             Nina Golgowski 2022-09-22
# ...                      ...        ...
# 209522      Reuters, Reuters 2012-01-28
# 209523                       2012-01-28
# 209524                       2012-01-28
# 209525                       2012-01-28
# 209526                       2012-01-28
#
#                                        headline_tokenized  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...
# 1       American Airlines Flyer Charged, Banned For Li...
# 2       23 Of The Funniest Tweets About Cats And Dogs ...
# 3       The Funniest Tweets From Parents This Week (Se...
# 4       Woman Who Called Cops On Black Bird-Watcher Lo...
# ...                                                   ...
# 209522  RIM CEO Thorsten Heins' 'Significant' Plans Fo...
# 209523  Maria Sharapova Stunned By Victoria Azarenka I...
# 209524  Giants Over Patriots, Jets Over Colts Among  M...
# 209525  Aldon Smith Arrested: 49ers Linebacker Busted ...
# 209526  Dwight Howard Rips Teammates After Magic Loss ...
#
#                               short_description_tokenized
# 0       Health experts said it is too early to predict...
# 1       He was subdued by passengers and crew when he ...
# 2       "Until you have a dog you don't understand wha...
# 3       "Accidentally put grown-up toothpaste on my to...
# 4       Amy Cooper accused investment firm Franklin Te...
# ...                                                   ...
# 209522  Verizon Wireless and AT&T are already promotin...
# 209523  Afterward, Azarenka, more effusive with the pr...
# 209524  Leading up to Super Bowl XLVI, the most talked...
# 209525  CORRECTION: An earlier version of this story i...
# 209526  The five-time all-star center tore into his te...
#
# [209527 rows x 8 columns]

# %% [markdown]
# # Removing punctuation

# %%
def remove_punct(text):
    no_punct="".join([a for a in text if a not in string.punctuation])
    return no_punct

# %%
df['headline_no_punct']=df['headline_cleaned'].apply(lambda x: remove_punct(x))
df['short_description_no_punct']=df['short_description_cleaned'].apply(lambda x: remove_punct(x))

# %%
for i in range(min(df.shape[0], 2)):
    temp=''
    tlist=nltk.word_tokenize(df['headline_no_punct'][i])
    for word in tlist:
        word=word.lower()
        if len(temp)!=0:
            temp += ' ' + WordNetLemmatizer().lemmatize(word)
        else: 
            temp += WordNetLemmatizer().lemmatize(word)
    print(tlist)
    print(temp)
# Out:
# ['Over', '4', 'Million', 'Americans', 'Roll', 'Up', 'Sleeves', 'For', 'OmicronTargeted', 'COVID', 'Boosters']
# over 4 million american roll up sleeve for omicrontargeted covid booster
# ['American', 'Airlines', 'Flyer', 'Charged', 'Banned', 'For', 'Life', 'After', 'Punching', 'Flight', 'Attendant', 'On', 'Video']
# american airline flyer charged banned for life after punching flight attendant on video

# %%
for i in range(min(df.shape[0], 2)):
    temp=''
    tlist=nltk.word_tokenize(df['short_description_no_punct'][i])
    for word in tlist:
        word=word.lower()
        if len(temp)!=0:
            temp += ' ' + WordNetLemmatizer().lemmatize(word)
        else: 
            temp += WordNetLemmatizer().lemmatize(word)
    print(tlist)
    print(temp)
# Out:
# ['Health', 'experts', 'said', 'it', 'is', 'too', 'early', 'to', 'predict', 'whether', 'demand', 'would', 'match', 'up', 'with', 'the', '171', 'million', 'doses', 'of', 'the', 'new', 'boosters', 'the', 'US', 'ordered', 'for', 'the', 'fall']
# health expert said it is too early to predict whether demand would match up with the 171 million dos of the new booster the u ordered for the fall
# ['He', 'was', 'subdued', 'by', 'passengers', 'and', 'crew', 'when', 'he', 'fled', 'to', 'the', 'back', 'of', 'the', 'aircraft', 'after', 'the', 'confrontation', 'according', 'to', 'the', 'US', 'attorneys', 'office', 'in', 'Los', 'Angeles']
# he wa subdued by passenger and crew when he fled to the back of the aircraft after the confrontation according to the u attorney office in los angeles

# %%
df.head(5)
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date                                 headline_tokenized  \
# 0 2022-09-23  Over 4 Million Americans Roll Up Sleeves For O...
# 1 2022-09-23  American Airlines Flyer Charged, Banned For Li...
# 2 2022-09-23  23 Of The Funniest Tweets About Cats And Dogs ...
# 3 2022-09-23  The Funniest Tweets From Parents This Week (Se...
# 4 2022-09-22  Woman Who Called Cops On Black Bird-Watcher Lo...
#
#                          short_description_tokenized  \
# 0  Health experts said it is too early to predict...
# 1  He was subdued by passengers and crew when he ...
# 2  "Until you have a dog you don't understand wha...
# 3  "Accidentally put grown-up toothpaste on my to...
# 4  Amy Cooper accused investment firm Franklin Te...
#
#                                    headline_no_punct  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...
# 1  American Airlines Flyer Charged Banned For Lif...
# 2  23 Of The Funniest Tweets About Cats And Dogs ...
# 3  The Funniest Tweets From Parents This Week Sep...
# 4  Woman Who Called Cops On Black BirdWatcher Los...
#
#                           short_description_no_punct
# 0  Health experts said it is too early to predict...
# 1  He was subdued by passengers and crew when he ...
# 2  Until you have a dog you dont understand what ...
# 3  Accidentally put grownup toothpaste on my todd...
# 4  Amy Cooper accused investment firm Franklin Te...

# %% [markdown]
# # Single for-loop
# ### Tokenizing, removing punct, converting to lower case, removing stopwords, converting numbers to words, & lemmatizing
# Ideally we want a single for-loop to iterate through the cells in the column and make all the relevant changes in one go. So I just added all the other commands to the lemmatizing for-loop we already have.
#
# Ultimately we'll probably turn this for-loop into a function that we use for both the headlines and short descriptions, but just doing it for the 1st two headlines now, as proof of concept.
#
# **Still need**  to add stemming function, and then add command that will write the cleaned up data to the X_cleaned column for headlines & short desriptions (and remove print statements)

# %%
for i in range(min(df.shape[0], 2)):
    temp=''
    
    ## 1st we tokenize the words from the headlines
    tlist=nltk.word_tokenize(df['headline_tokenized'][i])
    
    ## 2nd we remove punctation
    tlist =[w for w in tlist if w not in string.punctuation]
    
    ## Next we convert numbers to word
    tlist=[num2words(w) if w.isnumeric() else w for w in tlist ]
    
    ## Then we convert to lowercase and remove stop words
    tlist=[w.lower() for w in tlist if not w.lower() in set(stopwords.words('english'))]
    
    ## This lemmatizes the words in tlist, and puts it back into a sting
    '''Ultimately we might not lemmatize words? might just stick with stemming?
       OR stem them and then lemmatize them any way, even if it just converts plurals to singulars? 
       it'll probably help at least a little bit.... 
       NEW: see note at end''' 
    for word in tlist:
        if len(temp)!=0:
            temp += ' ' + WordNetLemmatizer().lemmatize(word)
        else: 
            temp += WordNetLemmatizer().lemmatize(word) 
    print(tlist) # This prints list of processed words 
    print(temp) # This prints it in sting format 
    print( )
# Out:
# ['four', 'million', 'americans', 'roll', 'sleeves', 'omicron-targeted', 'covid', 'boosters']
# four million american roll sleeve omicron-targeted covid booster
#
# ['american', 'airlines', 'flyer', 'charged', 'banned', 'life', 'punching', 'flight', 'attendant', 'video']
# american airline flyer charged banned life punching flight attendant video

# %% [markdown]
# # Note about lemmatizing
# We said we probably wouldn't lemmatize, because nltk defaults to thinking that the word is a noun. Good news! nltk comes with a part-of speech tagger! it's nltk.pos_tag(list)
# https://www.nltk.org/book/ch05.html

# %%
# no need to run this until we've finished refining the cleaning for-loop
df.to_csv('./News_ds.csv')
